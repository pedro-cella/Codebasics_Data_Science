# %% [markdown]
# # Operator Overloading

# %% [markdown]
# ## Takeaways
# - Operator overloading allows you to define how operators like **<, >, ==, +, -, *, etc.** behave for custom objects.
# - **Classes** and **Objects** are at the core of **OOPS.**
# - Overloading operators makes your custom classes **more intuitive** and **easier to use.**
