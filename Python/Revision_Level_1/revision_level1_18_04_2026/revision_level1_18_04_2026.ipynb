# %% [markdown]
# # Revision - Level 1 - Pandas and Dataframes Basics

# %% [markdown]
# ## Level 1 — Fundamentals (1–4)

# %% [markdown]
# ## Mission 1
#
# Carrega o dataset movies.csv em um DataFrame.
#
# 👉 Depois:
#
# mostra as 5 primeiras linhas
# mostra o shape

# %%
import pandas as pd

# %%
df = pd.read_csv("movies.csv")

# %%
df.head(5)
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
# 4                      Thor: Love and Thunder   Hollywood          2022
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
# 3          7.9             Marvel Studios    180.0     854.0   Millions
# 4          6.8             Marvel Studios    250.0     670.0   Millions
#
#   currency language
# 0      INR  Bengali
# 1      USD  English
# 2      USD  English
# ...

# %%
df.shape
# Out:
# (37, 10)

# %% [markdown]
# ## Mission 2
#
# Liste todas as colunas do DataFrame.
#
# 👉 Depois:
#
# verifique quantas colunas existem

# %%
df.columns
# Out:
# Index(['title', 'industry', 'release_year', 'imdb_rating', 'studio', 'budget',
#        'revenue', 'unit', 'currency', 'language'],
#       dtype='str')

# %%
len(df.columns)
# Out:
# 10

# %% [markdown]
# ## Mission 3
#
# Descubra:
#
# quantos filmes existem por industry
#
# 👉 (contagem)

# %%
df.industry.value_counts()
# Out:
# industry
# Hollywood    20
# Bollywood    17
# Name: count, dtype: int64

# %% [markdown]
# ## Mission 4
#
# Descubra:
#
# quantos filmes existem por language
#
# 👉 (ranking)

# %%
df["language"].value_counts()
# Out:
# language
# English    20
# Hindi      12
# Telugu      3
# Bengali     1
# Kannada     1
# Name: count, dtype: int64

# %% [markdown]
# ## Level 2 — Selections and Filters (5–7)

# %% [markdown]
# ## Mission 5
#
# Crie um novo DataFrame contendo apenas:
#
# title
# imdb_rating
# industry

# %%
df_new = df[["title", "imdb_rating", "industry"]]
df_new
# Out:
#                                           title  imdb_rating   industry
# 0                               Pather Panchali          8.3  Bollywood
# 1   Doctor Strange in the Multiverse of Madness          7.0  Hollywood
# 2                         Thor: The Dark World           6.8  Hollywood
# 3                               Thor: Ragnarok           7.9  Hollywood
# 4                       Thor: Love and Thunder           6.8  Hollywood
# 5                      The Shawshank Redemption          9.3  Hollywood
# 6                                  Interstellar          8.6  Hollywood
# 7                      The Pursuit of Happyness          8.0  Hollywood
# 8                                     Gladiator          8.5  Hollywood
# 9                                       Titanic          7.9  Hollywood
# 10                        It's a Wonderful Life          8.6  Hollywood
# 11                                       Avatar          7.8  Hollywood
# ...

# %% [markdown]
# ## Mission 6
#
# Filtre apenas os filmes:
#
# 👉 com release_year > 2010

# %%
df[df.release_year > 2010]
# Out:
#                                           title   industry  release_year  \
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 6                                  Interstellar  Hollywood          2014
# 16                                     Parasite  Hollywood          2019
# 17                            Avengers: Endgame  Hollywood          2019
# 18                       Avengers: Infinity War  Hollywood          2018
# 19           Captain America: The First Avenger  Hollywood          2011
# 20          Captain America: The Winter Soldier  Hollywood          2014
# 24                             Bajirao Mastani   Bollywood          2015
# 27                                           PK  Bollywood          2014
# ...

# %% [markdown]
# ## Mission 7
#
# Filtre os filmes que:
#
# - 👉 são de Hollywood
# - 👉 E possuem imdb_rating > 8

# %%
df[(df.industry == "Hollywood") & (df["imdb_rating"] > 8)]
# Out:
#                        title   industry  release_year  imdb_rating  \
# 5   The Shawshank Redemption  Hollywood          1994          9.3
# 6               Interstellar  Hollywood          2014          8.6
# 8                  Gladiator  Hollywood          2000          8.5
# 10     It's a Wonderful Life  Hollywood          1946          8.6
# 12             The Godfather  Hollywood          1972          9.2
# 13           The Dark Knight  Hollywood          2008          9.0
# 14          Schindler's List  Hollywood          1993          9.0
# 15             Jurassic Park  Hollywood          1993          8.2
# 16                  Parasite  Hollywood          2019          8.5
# 17         Avengers: Endgame  Hollywood          2019          8.4
# 18    Avengers: Infinity War  Hollywood          2018          8.4
#
#                        studio  budget  revenue      unit currency language
# 5   Castle Rock Entertainment   25.00     73.3  Millions      USD  English
# ...

# %% [markdown]
# ## Level 3 — Analysis and Logic (8–10)

# %% [markdown]
# ## Mission 8
#
# Descubra:
#
# - maior nota (imdb_rating)
# - menor nota
# - média

# %%
print(df.imdb_rating.max())
# Out:
# 9.3

# %%
print(df.imdb_rating.min())
# Out:
# 1.9

# %%
print(df.imdb_rating.mean())
# Out:
# 7.919444444444445

# %% [markdown]
# ## Mission 9
#
# Encontre:
#
# 👉 o filme com:
#
# - maior nota
# - menor nota
#
# (Dica: usa condição com max/min)

# %%
df[(df.imdb_rating == df.imdb_rating.max()) | (df["imdb_rating"] == df["imdb_rating"].min())]
# Out:
#                        title   industry  release_year  imdb_rating  \
# 5   The Shawshank Redemption  Hollywood          1994          9.3
# 31                    Race 3  Bollywood          2018          1.9
#
#                        studio  budget  revenue      unit currency language
# 5   Castle Rock Entertainment    25.0     73.3  Millions      USD  English
# 31          Salman Khan Films     1.8      3.1  Billions      INR    Hindi

# %% [markdown]
# ## Mission 10
#
# Crie uma nova coluna chamada:
#
# 👉 profit
#
# Onde:
#
# profit = revenue - budget

# %%
df["profit"] = df["revenue"] - df["budget"]
df
# Out:
#                                           title   industry  release_year  \
# 0                               Pather Panchali  Bollywood          1955
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 5                      The Shawshank Redemption  Hollywood          1994
# 6                                  Interstellar  Hollywood          2014
# 7                      The Pursuit of Happyness  Hollywood          2006
# 8                                     Gladiator  Hollywood          2000
# 9                                       Titanic  Hollywood          1997
# 10                        It's a Wonderful Life  Hollywood          1946
# 11                                       Avatar  Hollywood          2009
# ...

# %%
df["profit"] = df.apply(lambda x: x["revenue"] - x["budget"], axis=1)
df
# Out:
#                                           title   industry  release_year  \
# 0                               Pather Panchali  Bollywood          1955
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 5                      The Shawshank Redemption  Hollywood          1994
# 6                                  Interstellar  Hollywood          2014
# 7                      The Pursuit of Happyness  Hollywood          2006
# 8                                     Gladiator  Hollywood          2000
# 9                                       Titanic  Hollywood          1997
# 10                        It's a Wonderful Life  Hollywood          1946
# 11                                       Avatar  Hollywood          2009
# ...

# %% [markdown]
# ## 🧠 EXTRA CHALLENGE (Optional 😈)

# %% [markdown]
# ## Mission 11
#
# Crie uma coluna chamada:
#
# 👉 age do filme
#
# Baseado no ano atual.

# %%
from datetime import date

df["age"] = df["release_year"].apply(lambda x: date.today().year - x)
df
# Out:
#                                           title   industry  release_year  \
# 0                               Pather Panchali  Bollywood          1955
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 5                      The Shawshank Redemption  Hollywood          1994
# 6                                  Interstellar  Hollywood          2014
# 7                      The Pursuit of Happyness  Hollywood          2006
# 8                                     Gladiator  Hollywood          2000
# 9                                       Titanic  Hollywood          1997
# 10                        It's a Wonderful Life  Hollywood          1946
# 11                                       Avatar  Hollywood          2009
# ...

# %% [markdown]
# ## Mission 12.
#
# Separe o DataFrame em dois:
#
# - Bollywood
# - Hollywood
#
# E calcule a média de rating de cada um.

# %%
df_h = df[df.industry == "Hollywood"]
print(df_h.imdb_rating.mean())
# Out:
# 8.130000000000003

# %%
df_b = df[df.industry == "Bollywood"]
print(df_b.imdb_rating.mean())
# Out:
# 7.656250000000001
