# %% [markdown]
# # Building APIs with FastAPI

# %% [markdown]
# ## Takeaways
# - **FastAPI** is a web framework that **lets** you build servers that can serve inference requests.
# - **FastAPI** is modern framework that offers several benefits over other options such as **Flask**. The benefits are:
#     - Speed
#     - In built data validation
#     - In built documentation
#     - Faster code development
