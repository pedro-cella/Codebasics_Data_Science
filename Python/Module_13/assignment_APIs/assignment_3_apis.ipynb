# %% [markdown]
# <h2 align="center" style="color:blue">Codebasics Python Course: Exercise - APIs in Python</h2>

# %% [markdown]
# The Open Brewery DB API offers detailed data on various breweries across the United States.
#
# --
#
# ### Task 1: Fetch Brewery Data for Non-alcoholic Drink manufacturer - US client
#
# **Scenario:**
#
# As Tony Sharma mentioned during the call, he needs details about all the breweries in a specific state.
#
# Your task is to use the Open Brewery DB API to fetch and display brewery details based on a given state, which will be helpful for his client call tomorrow.
#
# **Write a Python program that:**
#
# 1. Uses the `requests` library to call the Open Brewery DB API to fetch brewery data based on a given state.
# 2. Parses the JSON response.
# 3. Extracts and displays the name, type, and location (city) of each brewery.
# 4. Handles errors gracefully (e.g., network issues or invalid API requests).
#
# Example URL for Texas Breweries: `https://api.openbrewerydb.org/breweries?by_state=texas`

# %%
# write your code here
import requests

def get_brewery_data(state):
    url = f"https://api.openbrewerydb.org/v1/breweries?by_state={state}"
    try:
        response = requests.get(url)
        response.raise_for_status()
        breweries = response.json()
        if not breweries:
            return "No breweries found in the specified state."
        return breweries
    except requests.exceptions.HTTPError as err:
        return f"HTTP error occurred: {err}"
    except Exception as err:
        return f"An error occurred: {err}"

state = "alabama"
breweries = get_brewery_data(state)
for brewery in breweries:
    name = brewery['name']
    brewery_type = brewery['brewery_type']
    city = brewery['city']
    print(f"- {name} ({brewery_type}) located in {city}")
# Out:
# - 5 Rivers Brewing LLC (planning) located in Spanish Fort
# - Avondale Brewing Co (micro) located in Birmingham
# - Back Forty Beer Company - Birmingham (micro) located in Birmingham
# - Back Forty Beer Company - Gadsden (micro) located in Gadsden
# - Back Forty Beer Company - Huntsville (brewpub) located in Huntsville
# - Band of Brothers Brewing Company (closed) located in Tuscaloosa
# - Below the Radar Brewing Co (closed) located in Huntsville
# - Big Beach Brewing Company (micro) located in Gulf Shores
# - Birmingham District Brewing (taproom) located in Birmingham
# - Black Warrior Brewing Co. (micro) located in Tuscaloosa
# - Blue Pants Brewery (closed) located in Madison
# - Bluewater Brewing Co (closed) located in Florence
# - Braided River Brewing Company (taproom) located in Mobile
# - Brewpub In Planning - Birmingham (planning) located in Birmingham
# - Cahaba Brewing Co (micro) located in Birmingham
# - Chandler's Ford Brewing LLC (brewpub) located in Huntsville
# - Chattahoochee Brewing Co (closed) located in Phenix City
# - Cheaha Brewing Co (closed) located in Anniston
# - Common Bond Brewers (micro) located in Montgomery
# - Cross-Eyed Owl Brewing Co. (micro) located in Decatur
# - Druid City Brewing (micro) located in Tuscaloosa
# - Fairhope Brewing Co (micro) located in Fairhope
# - Ferus Artisan Ales (brewpub) located in Trussville
# - Folklore Brewing (micro) located in Dothan
# - Ghost Train Brewing Co (micro) located in Birmingham
# - Goat Island Brewing (micro) located in Cullman
# - Good People Brewing Co (micro) located in Birmingham
# - Green Bus Brewing (brewpub) located in Huntsville
# - Haint Blue Brewing Company (closed) located in Mobile
# - InnerSpace Brewing Company (micro) located in Huntsville
# - Iron Hand Brewing (brewpub) located in Mobile
# - Mad Malts Brewery & Tap Room (micro) located in Huntsville
# - Main Channel Brewing Company (micro) located in Guntersville
# - Old Black Bear Brewing (micro) located in Madison
# - Old Majestic Brewing Company (closed) located in Mobile
# - Oversoul Brewing Company (closed) located in Helena
# - Red Clay Brewing Company (micro) located in Opelika
# - Red Hills Brewing Co (closed) located in Birmingham
# - Rocket Republic Brewing Company (closed) located in Madison
# - Salty Nut Brewery (closed) located in Huntsville
# - Sand Mtn brewery (planning) located in Section
# - Serda Brewing Company (closed) located in Mobile
# - Siluria Brewing Company (micro) located in Alabaster
# - Singin' River Brewing Company, LLC (micro) located in Florence
# - Slag Heap Brewing Company (closed) located in Trussville
# - Straight to Ale (micro) located in Huntsville
# - Tallulah Brewing Company (micro) located in Jasper
# - The Railyard Brewing Co (closed) located in Montgomery
# - Trim Tab Brewing (micro) located in Birmingham
# - True Story Brewing (taproom) located in Birmingham

# %% [markdown]
# JSONPlaceholder offers a set of APIs for typical CRUD (Create, Read, Update, Delete) operations, making it an excellent resource for learning and testing HTTP requests.
#
# --
#
# ### Task 2: Fetch User Data for AtliQ Client Project
#
# **Scenario:** As a quick favor, Loki shared an ad-hoc task with you. He needs help with a user profile component for an Atliq client application, using JSONPlaceholder to simulate fetching user data.
#
# **Objective:** Create a function `fetch_user_data` that uses JSONPlaceholder’s API to retrieve and format user details.
#
# **Steps:**
#
# 1. Fetch user data from JSONPlaceholder.
# 2. Format the data to include 'name', 'email', and 'address'.
# 3. Return the data as a dictionary.
#
# **Expected Output:**
#
# ```
# {
#     'name': 'Leanne Graham',
#     'email': 'Sincere@april.biz',
#     'address': 'Kulas Light, Gwenborough'
# }
#
#
#
# ```

# %%
# write your code here
def fetch_user_data(user_id):
    url = f"https://jsonplaceholder.typicode.com/users/{user_id}"
    try:
        response = requests.get(url)
        response.raise_for_status()
        user_data = response.json()
        user = {
            'name': user_data['name'],
            'email': user_data['email'],
            'address': f"{user_data['address']['street']}, {user_data['address']['city']}"
        }
        return user
    except requests.exceptions.HTTPError as err:
        return f"HTTP error occurred: {err}"
    except Exception as err:
        return f"An error occurred: {err}"

user_id = 1
user_info = fetch_user_data(user_id)
user_info
# Out:
# {'name': 'Leanne Graham',
#  'email': 'Sincere@april.biz',
#  'address': 'Kulas Light, Gwenborough'}
