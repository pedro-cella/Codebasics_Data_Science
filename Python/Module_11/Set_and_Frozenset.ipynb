# %% [markdown]
# # Set and Frozenset
# - Set allowed only non repetitive values

# %%
myset = set([1,2,3,2,3,4])
myset
# Out:
# {1, 2, 3, 4}

# %%
myset = {1, 2, 3, 4, 3, 4}
myset
# Out:
# {1, 2, 3, 4}

# %%
menu = set(["Dosa", "Idli", "Biryani"])
menu
# Out:
# {'Biryani', 'Dosa', 'Idli'}

# %%
menu.add("Pizza")
menu
# Out:
# {'Biryani', 'Dosa', 'Idli', 'Pizza'}

# %%
menu.remove("Dosa")
menu
# Out:
# {'Biryani', 'Idli', 'Pizza'}

# %%
menu = frozenset(["Dosa", "Idli", "Biryani"])
menu
# Out:
# frozenset({'Biryani', 'Dosa', 'Idli'})

# %%
menu.add("Pizza")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 menu.add("Pizza")
#
# AttributeError: 'frozenset' object has no attribute 'add'

# %%
menu = set(["Dosa", "Idli", "Biryani"])
menu
# Out:
# {'Biryani', 'Dosa', 'Idli'}

# %%
"Dosa" in menu
# Out:
# True

# %%
"Burger" in menu
# Out:
# False

# %%
transactions = [
    {'customer_name': 'Mira', "amount": 56, "date": "2024-08-01"},
    {'customer_name': 'Mira', "amount": 12.3, "date": "2024-09-05"},
    {'customer_name': 'Mohan', "amount": 21, "date": "2024-09-03"},
    {'customer_name': 'Mohan', "amount": 36.8, "date": "2024-09-10"},
    {'customer_name': 'Lucy', "amount": 66.3, "date": "2024-09-10"},
]

# %%
customers = set()
for trans in transactions:
    customers.add(trans['customer_name'])

customers
# Out:
# {'Lucy', 'Mira', 'Mohan'}

# %%
customers_list = list(customers)
customers_list
# Out:
# ['Mira', 'Lucy', 'Mohan']

# %%
a = {"Mira", "Mohan", "Lucy", "Ahmed"}
b = {"Chen", "Mohan", "Radha", "Maria"}

# %%
a & b
# Out:
# {'Mohan'}

# %%
a.intersection(b)
# Out:
# {'Mohan'}

# %%
a | b
# Out:
# {'Ahmed', 'Chen', 'Lucy', 'Maria', 'Mira', 'Mohan', 'Radha'}

# %%
a.union(b)
# Out:
# {'Ahmed', 'Chen', 'Lucy', 'Maria', 'Mira', 'Mohan', 'Radha'}

# %%
a - b
# Out:
# {'Ahmed', 'Lucy', 'Mira'}

# %% [markdown]
# ## Takeaways
# - **Sets are mutable collections** that only store **unique elements** and **support efficient membership checks, additions,** and **deletions.**
# - **Frozensets** are immutable versions of sets, making them hashable and usable as dictionary keys or set elements
# - Both **sets** and **frozensets** support mathematical set operations like union, intersection, difference and symmetric difference.
# - Sets can be modified using methods like **add(), remove(),** and **update(),** while frozensets do not offer any methods that alter theur content.
# - Understanding sets and frozensets is crucial for optimizing performance in scenarios requiring the storage of non-repeating elements and fast lookups.
