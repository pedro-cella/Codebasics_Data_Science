# %% [markdown]
# # Numbers
# - e4 is equivalent to the number of 0's after 1;
# - ```Shift``` + ```TAB``` shows the explanation of that function;
# - ```dir()``` shows all the functions of a library;
# - 1 bit = 0 or 1, 8 bits = 1 byte

# %%
base = 10
height = 7

area = (base * height)/2
area
# Out:
# 35.0

# %%
type(area)
# Out:
# float

# %%
type(100)
# Out:
# int

# %%
x = 10
y = 3

x + y
# Out:
# 13

# %%
x - y
# Out:
# 7

# %%
x / y
# Out:
# 3.3333333333333335

# %%
x // y
# Out:
# 3

# %%
x % y
# Out:
# 1

# %%
x, y
# Out:
# (10, 3)

# %%
x**3
# Out:
# 1000

# %%
10 + 2 * 3
# Out:
# 16

# %%
(10+2)*3
# Out:
# 36

# %%
foo = 2.3e4
foo
# Out:
# 23000.0

# %%
1e4
# Out:
# 10000.0

# %%
1e2
# Out:
# 100.0

# %%
bar = 2.3e-3
bar
# Out:
# 0.0023

# %%
1e-3
# Out:
# 0.001

# %%
fafda = 5

# %%
fafda
# Out:
# 5

# %%
food = 120.34
rent = 500.4
utilities = 200.5

# %%
total = food+rent+utilities
total
# Out:
# 821.24

# %%
round(total, 3)
# Out:
# 821.24

# %%
income = 10000
expenses = 9000
saving = income-expenses
saving
# Out:
# 1000

# %%
food = "120.34"
rent = "500.67"

total = food + rent
total

# The problem with this calculation, is on the types of the variables, they are Strings, when you use "+" with two Strings, they concatenate instead of sum
# Out:
# '120.34500.67'

# %%
food = "120.34"
rent = "500.67"

# Convert strings to floats
total = float(food) + float(rent)
total
# Out:
# 621.01

# %%
food
# Out:
# '120.34'

# %%
type(food)
# Out:
# str

# %%
float(food)
# Out:
# 120.34

# %%
type(float(food))
# Out:
# float

# %%
import math

x = 16
math.sqrt(x)
# Out:
# 4.0

# %%
math.floor(3.7)
# Out:
# 3

# %%
math.ceil(3.7)
# Out:
# 4

# %%
math.pi
# Out:
# 3.141592653589793

# %%
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fma',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
format(5, 'b')
# Out:
# '101'

# %% [markdown]
# ![image.png](attachment:53bbf7a6-3f0a-4b16-865d-50f00c4bbb32.png)
#
# IEEE Floating point standard
#
# Integer numbers are stored as binaries, this is the calculation you use to convert a binary to an integer number

# %% [markdown]
# ## Takeaways
# - **Integer** number store **whole numbers (whole decimal part)**, e.g. 57.
# - **Float** numbers store **fractional numbers with whole and decimal part**, e.g. 57.23.
# - **type(variable_name)** can be used **to detect the data type of a variable.**
# - **/ operator** is used **for division** whereas **//** is used **to retrieve integer part of the division**
# - **% is a modulo operator,** it returns the **remainder** of a division operator.
