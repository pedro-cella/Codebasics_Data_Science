# %% [markdown]
# # String - Exercises

# %%
help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to 'utf-8'.
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getitem__(self, key, /)
# ...

# %% [markdown]
# ## Exercise 1

# %%
string = "palavra de teste"
string2 = "ASASASA"
string_vector = ["TESTE", "TESTE", "apple"]

# %%
# Capitalize
string.capitalize()
# Out:
# 'Palavra de teste'

# %%
# Casefold -> Converte tudo para minusculo
string2.casefold()
# Out:
# 'asasasa'

# %%
# Center -> centraliza a posição de uma string
print(string2.center(20, 'T'))
print(string.center(20))
# Out:
# TTTTTTASASASATTTTTTT
#   palavra de teste

# %%
# Count
print(string_vector.count("TESTE"))
(string.count("a"))
# Out:
# 2
# 3

# %% [markdown]
# ## Exercise 2

# %%
fruits = 2
vegetables = 4

print(f'I eat {vegetables} and {fruits} fruits daily')
# Out:
# I eat 4 and 2 fruits daily

# %% [markdown]
# ## Exercise 3

# %%
variable = "The Himalayas are one of the youngest mountain ranges on the planet."
print(variable[:14])
# Out:
# The Himalayas

# %%
print(variable[-30:-14])
# Out:
# mountain ranges

# %%
print(f'{variable[:14]}{variable[-14:]}')
# Out:
# The Himalayas on the planet.

# %% [markdown]
# ## Exercise 4

# %%
string= "There are 9 planets in the solar system"

# %%
string = string.replace("9", "8")
string
# Out:
# 'There are 8 planets in the solar system'

# %%
empty_string = "AI Engineer"
print(len(empty_string))
# Out:
# 11
